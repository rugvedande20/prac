# %% [markdown]
# # Data Visualization III
#  Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
# https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:
#  1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
#  2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
#  3. Create a boxplot for each feature in the dataset.
#  4. Compare distributions and identify outliers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset("iris")
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # FEATURE

# %%
print("\n 1.FEATURE AND THEIR TYPES:")
print(data.dtypes)
print("\n Summary:")
for column in data.columns:
    dtype=data[column].dtype
    if dtype=="object":
        print(f"{column}:Nominal")
    else:
        print(f"{column}:Numeric")
# Out:
#  1.FEATURE AND THEIR TYPES:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object
#
#  Summary:
# sepal_length:Numeric
# sepal_width:Numeric
# petal_length:Numeric
# petal_width:Numeric
# species:Nominal

# %% [markdown]
# # HISTOGRAM

# %%
print("\n 2. Histogram for feature")
numeric_feature=data.select_dtypes(include="number").columns
data[numeric_feature].hist(figsize=(10,6),color="lightblue",edgecolor="black")
plt.suptitle("Histogram for feature")
plt.tight_layout()
plt.show()
# Out:
#  2. Histogram for feature

# %%
sns.histplot(data["petal_length"],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data["petal_width"],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data["sepal_length"],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data["sepal_width"],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(x="species",y="petal_length",data=data,bins=20)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.histplot(x="species",y="petal_width",data=data,bins=20)
# Out:
# <Axes: xlabel='species', ylabel='petal_width'>

# %%
sns.histplot(x="species",y="sepal_length",data=data,bins=20)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.histplot(x="species",y="sepal_width",data=data,bins=20)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# # BOXPLOT

# %%
print("\n 3 Boxplot of feature")
plt.figure(figsize=(10,6))
for i, feature in enumerate(numeric_feature,1):
    plt.subplot(2,2,i)
    sns.boxplot(y=data[feature],color="lightblue")
    plt.title(f"Boxplot of {feature}")
plt.tight_layout()
plt.show()
# Out:
#  3 Boxplot of feature

# %%
sns.boxplot(data["sepal_length"])
# Out:
# <Axes: ylabel='sepal_length'>

# %%
sns.boxplot(data=data,x="species",y="petal_length",palette="pastel")
# Out:
# C:\Users\Shri\AppData\Local\Temp\ipykernel_9212\3904988510.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data,x="species",y="petal_length",palette="pastel")
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # OUTLIERS

# %%
print("\n 4 Outliers")
for feature in numeric_feature:
    Q1=data[feature].quantile(0.25)
    Q3=data[feature].quantile(0.75)
    IQR=Q3-Q1
    lower=Q1-1.5 * IQR
    upper=Q3+1.5 * IQR
    outlier=data[(data[feature]<lower)|(data[feature]>upper)]
    print(f"{feature}:{len(outlier)} dected")
# Out:
#  4 Outliers
# sepal_length:0 dected
# sepal_width:4 dected
# petal_length:0 dected
# petal_width:0 dected

# %%
sns.boxplot(data=data ,y="sepal_width",hue="species",palette="pastel")
# Out:
# <Axes: ylabel='sepal_width'>

# %%
sns.boxplot(data=data ,y="petal_width",hue="species",palette="pastel")
# Out:
# <Axes: ylabel='petal_width'>

# %%
sns.boxplot(data=data ,y="petal_length",hue="species",palette="pastel")
# Out:
# <Axes: ylabel='petal_length'>

# %%
sns.boxplot(data["sepal_width"])
# Out:
# <Axes: ylabel='sepal_width'>

# %%
numerical_col = ['sepal_length','sepal_width','petal_length','petal_width'] 
categorical_col = ['species'] 
data.boxplot(numerical_col)
# Out:
# <Axes: >

# %%
sns.boxplot(data)
# Out:
# <Axes: >
